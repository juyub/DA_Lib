# %% [markdown]
# # BC 카드 소비 데이터 분석
#
# ## 1. 데이터 로딩 및 전처리
# ### 1-1. 데이터 로딩 to DataFrame
# - 전처리하여 csv로 저장한 파일 '201906.csv'을 판다스 dataframe으로 로딩 (encoding='utf-8', index_col=0)
# - 앞부분 데이터 확인
# - 전체 데이터 수 확인

# %%
import pandas as pd
bc_card = pd.read_csv('bc_data_201906.csv', encoding='utf-8', index_col=0)
bc_card.head(5)
# Out:
#    REG_YYMM  MEGA_CTY_NO MEGA_CTY_NM  CTY_RGN_NO CTY_RGN_NM  ADMI_CTY_NO  \
# 0    201906           11       서울특별시        1162        관악구     11620585
# 1    201906           11       서울특별시        1159        동작구     11590560
# 2    201906           11       서울특별시        1162        관악구     11620595
# 3    201906           11       서울특별시        1144        마포구     11440660
# 4    201906           11       서울특별시        1120        성동구     11200550
#
#   ADMI_CTY_NM  MAIN_BUZ_CODE MAIN_BUZ_DESC  TP_GRP_NO  ... CSTMR_GUBUN  \
# 0        낙성대동             80            음식         80  ...         내국인
# 1        상도4동             30            생활         40  ...         내국인
# 2         청룡동             30            생활         83  ...         내국인
# 3         서교동             80            음식         80  ...         내국인
# 4         사근동             80            음식         80  ...         내국인
#
#    CSTMR_MEGA_CTY_NO CSTMR_MEGA_CTY_NM CSTMR_CTY_RGN_NO  CSTMR_CTY_RGN_NM  \
# 0                 11             서울특별시             1162               관악구
# 1                 11             서울특별시             1165               서초구
# 2                 11             서울특별시             1162               관악구
# 3                 11             서울특별시             1138               은평구
# 4                 11             서울특별시             1120               성동구
#
#   SEX_CTGO_CD  AGE_VAL FLC       AMT   CNT
# 0           2      30대   2  26284804  1892
# 1           2      20대   1    109290    18
# 2           1      20대   1    268850    52
# 3           1      20대   1  44174450  1790
# 4           1      20대   1  60338146  3536
#
# [5 rows x 23 columns]

# %%
len(bc_card)
# Out:
# 100001

# %% [markdown]
# ### 1-2. Data Cleaning (전처리)
# - 결측치 찾기 -> row 삭제 또는 mean/median/mod로 채우기

# %%
bc_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100001 entries, 0 to 100000
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   REG_YYMM           100001 non-null  int64
#  1   MEGA_CTY_NO        100001 non-null  int64
#  2   MEGA_CTY_NM        100001 non-null  object
#  3   CTY_RGN_NO         100001 non-null  int64
#  4   CTY_RGN_NM         100001 non-null  object
#  5   ADMI_CTY_NO        100001 non-null  int64
#  6   ADMI_CTY_NM        100001 non-null  object
#  7   MAIN_BUZ_CODE      100001 non-null  int64
#  8   MAIN_BUZ_DESC      100001 non-null  object
#  9   TP_GRP_NO          100001 non-null  int64
#  10  TP_GRP_NM          100001 non-null  object
#  11  TP_BUZ_NO          100001 non-null  int64
#  12  TP_BUZ_NM          100001 non-null  object
#  13  CSTMR_GUBUN        100001 non-null  object
#  14  CSTMR_MEGA_CTY_NO  100001 non-null  int64
#  15  CSTMR_MEGA_CTY_NM  100001 non-null  object
#  16  CSTMR_CTY_RGN_NO   100001 non-null  int64
#  17  CSTMR_CTY_RGN_NM   100001 non-null  object
#  18  SEX_CTGO_CD        100001 non-null  int64
#  19  AGE_VAL            100001 non-null  object
#  20  FLC                100001 non-null  int64
#  21  AMT                100001 non-null  int64
#  22  CNT                100001 non-null  int64
# dtypes: int64(13), object(10)
# memory usage: 18.3+ MB

# %% [markdown]
# * 중복값 찾기

# %%
bc_card[bc_card.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [REG_YYMM, MEGA_CTY_NO, MEGA_CTY_NM, CTY_RGN_NO, CTY_RGN_NM, ADMI_CTY_NO, ADMI_CTY_NM, MAIN_BUZ_CODE, MAIN_BUZ_DESC, TP_GRP_NO, TP_GRP_NM, TP_BUZ_NO, TP_BUZ_NM, CSTMR_GUBUN, CSTMR_MEGA_CTY_NO, CSTMR_MEGA_CTY_NM, CSTMR_CTY_RGN_NO, CSTMR_CTY_RGN_NM, SEX_CTGO_CD, AGE_VAL, FLC, AMT, CNT]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ## 2. 데이터 분석
# ### 2-1. 서울시 거주/비거주 고객의 소비 분석
# #### 2-2-1. 고개 데이터 분리
# * 고객 거주 도시 정보 : CSTMR_MEGA_CTY_NM : 서울특별시
# * seoul_card_df
# * nonseoul_card_df
#
# 1. 조건에 맞는 데이터의 index 추출
# 2. 해당 index 데이터 삭제한 df 저장
# 3. 새로 생성한 df의 index 재정렬 : reset_index(drop=True, inplace=True)

# %%
# 조건에 맞는 데이터의 index 추출
index1 = bc_card[bc_card['CSTMR_MEGA_CTY_NM'] != '서울특별시'].index

# 해당 index 데이터 삭제한 df 저장
seoul_card_df = bc_card.drop(index1)

# 새로 생성한 df의 index 재정렬
seoul_card_df.reset_index(drop=True, inplace=True)
seoul_card_df
# Out:
#        REG_YYMM  MEGA_CTY_NO MEGA_CTY_NM  CTY_RGN_NO CTY_RGN_NM  ADMI_CTY_NO  \
# 0        201906           11       서울특별시        1162        관악구     11620585
# 1        201906           11       서울특별시        1159        동작구     11590560
# 2        201906           11       서울특별시        1162        관악구     11620595
# 3        201906           11       서울특별시        1144        마포구     11440660
# 4        201906           11       서울특별시        1120        성동구     11200550
# ...         ...          ...         ...         ...        ...          ...
# 54145    201906           11       서울특별시        1156       영등포구     11560550
# 54146    201906           11       서울특별시        1132        도봉구     11320515
# 54147    201906           11       서울특별시        1171        송파구     11710642
# 54148    201906           11       서울특별시        1168        강남구     11680545
# 54149    201906           11       서울특별시        1117        용산구     11170520
#
#       ADMI_CTY_NM  MAIN_BUZ_CODE MAIN_BUZ_DESC  TP_GRP_NO  ... CSTMR_GUBUN  \
# 0            낙성대동             80            음식         80  ...         내국인
# 1            상도4동             30            생활         40  ...         내국인
# 2             청룡동             30            생활         83  ...         내국인
# 3             서교동             80            음식         80  ...         내국인
# 4             사근동             80            음식         80  ...         내국인
# ...           ...            ...           ...        ...  ...         ...
# 54145        당산1동             30            생활         61  ...         내국인
# 54146         창5동             20            문화         22  ...         내국인
# 54147        문정2동             10           T&E         21  ...         내국인
# 54148        압구정동             99            기타         91  ...         내국인
# 54149       용산2가동             30            생활         40  ...         내국인
#
#        CSTMR_MEGA_CTY_NO CSTMR_MEGA_CTY_NM CSTMR_CTY_RGN_NO  CSTMR_CTY_RGN_NM  \
# 0                     11             서울특별시             1162               관악구
# 1                     11             서울특별시             1165               서초구
# 2                     11             서울특별시             1162               관악구
# 3                     11             서울특별시             1138               은평구
# 4                     11             서울특별시             1120               성동구
# ...                  ...               ...              ...               ...
# 54145                 11             서울특별시             1147               양천구
# 54146                 11             서울특별시             1135               노원구
# 54147                 11             서울특별시             1171               송파구
# 54148                 11             서울특별시             1126               중랑구
# 54149                 11             서울특별시             1162               관악구
#
#       SEX_CTGO_CD  AGE_VAL FLC       AMT   CNT
# 0               2      30대   2  26284804  1892
# 1               2      20대   1    109290    18
# 2               1      20대   1    268850    52
# 3               1      20대   1  44174450  1790
# 4               1      20대   1  60338146  3536
# ...           ...      ...  ..       ...   ...
# 54145           1      40대   3    123000     3
# 54146           1      30대   2    406480     7
# 54147           2   60대 이상   5   3350000    10
# 54148           1      30대   2   1432000     3
# 54149           1      40대   2     38640     7
#
# [54150 rows x 23 columns]

# %%
index2 = bc_card[bc_card['CSTMR_MEGA_CTY_NM'] == '서울특별시'].index
nonseoul_card_df = bc_card.drop(index2)
nonseoul_card_df.reset_index(drop=True, inplace=True)
nonseoul_card_df
# Out:
#        REG_YYMM  MEGA_CTY_NO MEGA_CTY_NM  CTY_RGN_NO CTY_RGN_NM  ADMI_CTY_NO  \
# 0        201906           11       서울특별시        1114         중구     11140540
# 1        201906           11       서울특별시        1168        강남구     11680656
# 2        201906           11       서울특별시        1114         중구     11140550
# 3        201906           11       서울특별시        1144        마포구     11440555
# 4        201906           11       서울특별시        1156       영등포구     11560515
# ...         ...          ...         ...         ...        ...          ...
# 45846    201906           11       서울특별시        1114         중구     11140520
# 45847    201906           11       서울특별시        1165        서초구     11650520
# 45848    201906           11       서울특별시        1156       영등포구     11560535
# 45849    201906           11       서울특별시        1141       서대문구     11410585
# 45850    201906           11       서울특별시        1135        노원구     11350710
#
#       ADMI_CTY_NM  MAIN_BUZ_CODE MAIN_BUZ_DESC  TP_GRP_NO  ... CSTMR_GUBUN  \
# 0             회현동             10           T&E         11  ...         내국인
# 1            도곡2동             30            생활         40  ...         내국인
# 2              명동             10           T&E         20  ...         내국인
# 3             아현동             30            생활         40  ...         내국인
# 4           영등포본동             30            생활         41  ...         내국인
# ...           ...            ...           ...        ...  ...         ...
# 45846         소공동             30            생활         40  ...         내국인
# 45847        서초2동             30            생활         40  ...         내국인
# 45848        영등포동             30            생활         40  ...         내국인
# 45849         신촌동             40            쇼핑         42  ...         내국인
# 45850        상계9동             20            문화         51  ...         내국인
#
#        CSTMR_MEGA_CTY_NO CSTMR_MEGA_CTY_NM CSTMR_CTY_RGN_NO  CSTMR_CTY_RGN_NM  \
# 0                     47              경상북도             4713               경주시
# 1                     45              전라북도             4511               전주시
# 2                     28             인천광역시             2817              미추홀구
# 3                     26             부산광역시             2617                동구
# 4                     41               경기도             4117               안양시
# ...                  ...               ...              ...               ...
# 45846                 45              전라북도             4511               전주시
# 45847                 43              충청북도             4311               청주시
# 45848                 28             인천광역시             2817              미추홀구
# 45849                 44              충청남도             4413               천안시
# 45850                 41               경기도             4115              의정부시
#
#       SEX_CTGO_CD  AGE_VAL FLC       AMT   CNT
# 0               2      30대   2   3759530   463
# 1               2      30대   2  36909050  3465
# 2               1      20대   1  10002400   117
# 3               2      30대   2  43811379  1426
# 4               1      50대   3    279850    54
# ...           ...      ...  ..       ...   ...
# 45846           1      40대   3    971830    13
# 45847           1      50대   4     50600    10
# 45848           2      30대   2    340590    15
# 45849           1      20대   2    117100     3
# 45850           1      40대   3   5227500     7
#
# [45851 rows x 23 columns]

# %% [markdown]
# #### 2-2-2. 고객수 구하기

# %%
print(f'서울 거주 고객 : {len(seoul_card_df):,}명')
print(f'서울 비거주 고객 : {len(nonseoul_card_df):,}명')
# Out:
# 서울 거주 고객 : 54,150명
# 서울 비거주 고객 : 45,851명

# %% [markdown]
# #### 2-2-3. 총 소비액 구하기
# * 소비액 : AMT
# * *dataframe* / *series* . **sum**(axis=0)
# * f-string 포맷팅 형식 지시자 ':,'

# %%
print(f"서울 거주 고객 총 소비액 : {seoul_card_df['AMT'].sum(axis=0):,}원")
print(f"서울 비거주 고객 총 소비액 : {nonseoul_card_df['AMT'].sum(axis=0):,}원")
# Out:
# 서울 거주 고객 총 소비액 : 119,663,142,676원
# 서울 비거주 고객 총 소비액 : 146,587,135,822원

# %% [markdown]
# #### 2-2-4. 카드 이용 건수 구하기
# * 이용 건수 : CNT

# %%
print(f"서울 거주 고객 총 이용 건수 : {seoul_card_df['CNT'].sum(axis=0):,}건")
print(f"서울 비거주 고객 총 이용 건수 : {nonseoul_card_df['CNT'].sum(axis=0):,}건")
# Out:
# 서울 거주 고객 총 이용 건수 : 5,542,462건
# 서울 비거주 고객 총 이용 건수 : 4,950,200건

# %% [markdown]
# #### [참고] 특정 데이터를 기준으로 집계하기 : pivot_table
# * *pandas*.**pivot_table** (data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True)
#   - data : 피벗할 데이터가 들어 있는 데이터프레임
#   - values: 집계할 열(데이터)
#   - index: 행 인덱스 지정
#   - columns: 열 이름 지정
#   - aggfunc: 집계 함수, 기본값은 'mean' 다른 함수('sum', 'count', 'max', 'min' 등) 지정 가능
#   - fill_value: 결측치를 대체할 값
#   - margins: 부분 합계를 나타낼지 여부
#   - dropna: NaN 값을 가진 행 또는 열을 제거할지 여부

# %%
import pandas as pd

# 예제 데이터프레임 생성
data = {'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
        'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
        'C': [1, 2, 3, 4, 5, 6, 7, 8]}

df = pd.DataFrame(data)
df
# Out:
#      A      B  C
# 0  foo    one  1
# 1  bar    one  2
# 2  foo    two  3
# 3  bar  three  4
# 4  foo    two  5
# 5  bar    two  6
# 6  foo    one  7
# 7  foo  three  8

# %%
# pivot_table을 사용하여 데이터를 재구성
#'A' 열을 행 인덱스로, 'B' 열을 열 이름으로 사용하여 'C' 열의 합 값을 집계한 결과를 출력
pivot = pd.pivot_table(df, values='C', aggfunc='sum', index='A', columns='B')
pivot
# Out:
# B    one  three  two
# A
# bar    2      4    6
# foo    8      8    8

# %% [markdown]
# #### 2-2-4. 성별 소비액 구하기
# * 남녀 구분 : SEX_CTGO_CD (1:남성, 2:여성)
#
# * 서울 거주자 남녀별 소비액 pivot_table
# * 서울 비거주자 남녀별 소비액 pivot_table

# %%
seoul_sex = pd.pivot_table(seoul_card_df, values=['AMT','CNT'], aggfunc='sum', index=['SEX_CTGO_CD'])
seoul_sex
# Out:
#                      AMT      CNT
# SEX_CTGO_CD
# 1            58128378947  2862937
# 2            61534763729  2679525

# %%
nonseoul_sex = pd.pivot_table(nonseoul_card_df, values=['AMT','CNT'], aggfunc='sum', index=['SEX_CTGO_CD'])
nonseoul_sex
# Out:
#                      AMT      CNT
# SEX_CTGO_CD
# 1            73579570815  2615702
# 2            73007565007  2334498

# %% [markdown]
# * 이해하기 쉽게 출력하기
#   - 서울 거주자 : 남성, 여성
#   - 서울 비거주자 : 남성, 여성

# %%
print("* 서울시 거주자의 남녀별 현황")
print(f"  - 남성 : {seoul_sex.loc[1, 'CNT']:,}건, {seoul_sex.loc[1, 'AMT']:,}원")

print(f"서울 거주자 :  남성({seoul_sex.loc[1, 'AMT']:,}원), 여성({seoul_sex.loc[2, 'AMT']:,}원)")
print(f"서울 거주자 :  남성({seoul_sex.loc[1, 'CNT']:,}건), 여성({seoul_sex.loc[2, 'CNT']:,}건)")
# Out:
# * 서울시 거주자의 남녀별 현황
#   - 남성 : 2,862,937건, 58,128,378,947원
# 서울 거주자 :  남성(58,128,378,947원), 여성(61,534,763,729원)
# 서울 거주자 :  남성(2,862,937건), 여성(2,679,525건)

# %%
print(f"서울 비거주자 :  남성({nonseoul_sex.loc[1, 'AMT']:,}원), 여성({nonseoul_sex.loc[2, 'AMT']:,}원)")
print(f"서울 비거주자 :  남성({nonseoul_sex.loc[1, 'CNT']:,}건, 여성({nonseoul_sex.loc[2, 'CNT']:,}건)")
# Out:
# 서울 비거주자 :  남성(73,579,570,815원), 여성(73,007,565,007원)
# 서울 비거주자 :  남성(2,615,702건, 여성(2,334,498건)

# %% [markdown]
# ### 2-2. 편의점 소비 정보 분석

# %% [markdown]
# #### 2-2-1. 편의점 소비액 구하기
# * 편의점 소비 데이터 추출
#   - 매장 유형 정보 : TP_BUZ_NO - 4010 (편의점)
#   - 소비액 : AMT

# %%
index3 = bc_card[bc_card['TP_BUZ_NO'] != 4010].index
cov_df = bc_card.drop(index3)
cov_df.reset_index(drop=True, inplace=True)
cov_df
# Out:
#        REG_YYMM  MEGA_CTY_NO MEGA_CTY_NM  CTY_RGN_NO CTY_RGN_NM  ADMI_CTY_NO  \
# 0        201906           11       서울특별시        1159        동작구     11590560
# 1        201906           11       서울특별시        1168        강남구     11680521
# 2        201906           11       서울특별시        1168        강남구     11680545
# 3        201906           11       서울특별시        1138        은평구     11380690
# 4        201906           11       서울특별시        1174        강동구     11740685
# ...         ...          ...         ...         ...        ...          ...
# 11507    201906           11       서울특별시        1121        광진구     11215710
# 11508    201906           11       서울특별시        1174        강동구     11740550
# 11509    201906           11       서울특별시        1132        도봉구     11320514
# 11510    201906           11       서울특별시        1165        서초구     11650520
# 11511    201906           11       서울특별시        1117        용산구     11170520
#
#       ADMI_CTY_NM  MAIN_BUZ_CODE MAIN_BUZ_DESC  TP_GRP_NO  ... CSTMR_GUBUN  \
# 0            상도4동             30            생활         40  ...         내국인
# 1            논현1동             30            생활         40  ...         내국인
# 2            압구정동             30            생활         40  ...         내국인
# 3             진관동             30            생활         40  ...         내국인
# 4              길동             30            생활         40  ...         내국인
# ...           ...            ...           ...        ...  ...         ...
# 11507         화양동             30            생활         40  ...         내국인
# 11508        고덕1동             30            생활         40  ...         내국인
# 11509         창4동             30            생활         40  ...         내국인
# 11510        서초2동             30            생활         40  ...         내국인
# 11511       용산2가동             30            생활         40  ...         내국인
#
#        CSTMR_MEGA_CTY_NO CSTMR_MEGA_CTY_NM CSTMR_CTY_RGN_NO  CSTMR_CTY_RGN_NM  \
# 0                     11             서울특별시             1165               서초구
# 1                     11             서울특별시             1150               강서구
# 2                     11             서울특별시             1168               강남구
# 3                     11             서울특별시             1138               은평구
# 4                     11             서울특별시             1171               송파구
# ...                  ...               ...              ...               ...
# 11507                 41               경기도             4182               가평군
# 11508                 41               경기도             4136              남양주시
# 11509                 41               경기도             4117               안양시
# 11510                 43              충청북도             4311               청주시
# 11511                 11             서울특별시             1162               관악구
#
#       SEX_CTGO_CD  AGE_VAL FLC      AMT  CNT
# 0               2      20대   1   109290   18
# 1               2      20대   1  1461800  274
# 2               1      30대   3   230730   34
# 3               1      20대   2  1087940  154
# 4               1      40대   3  2569590  361
# ...           ...      ...  ..      ...  ...
# 11507           1   60대 이상   5    69940    6
# 11508           2      40대   3    68980   15
# 11509           2      40대   3    12200    3
# 11510           1      50대   4    50600   10
# 11511           1      40대   2    38640    7
#
# [11512 rows x 23 columns]

# %%
cov_df2 = bc_card[bc_card['TP_BUZ_NO'] == 4010]
cov_df2
# Out:
#        REG_YYMM  MEGA_CTY_NO MEGA_CTY_NM  CTY_RGN_NO CTY_RGN_NM  ADMI_CTY_NO  \
# 1        201906           11       서울특별시        1159        동작구     11590560
# 6        201906           11       서울특별시        1168        강남구     11680521
# 12       201906           11       서울특별시        1168        강남구     11680545
# 16       201906           11       서울특별시        1138        은평구     11380690
# 19       201906           11       서울특별시        1174        강동구     11740685
# ...         ...          ...         ...         ...        ...          ...
# 99982    201906           11       서울특별시        1121        광진구     11215710
# 99991    201906           11       서울특별시        1174        강동구     11740550
# 99993    201906           11       서울특별시        1132        도봉구     11320514
# 99996    201906           11       서울특별시        1165        서초구     11650520
# 99997    201906           11       서울특별시        1117        용산구     11170520
#
#       ADMI_CTY_NM  MAIN_BUZ_CODE MAIN_BUZ_DESC  TP_GRP_NO  ... CSTMR_GUBUN  \
# 1            상도4동             30            생활         40  ...         내국인
# 6            논현1동             30            생활         40  ...         내국인
# 12           압구정동             30            생활         40  ...         내국인
# 16            진관동             30            생활         40  ...         내국인
# 19             길동             30            생활         40  ...         내국인
# ...           ...            ...           ...        ...  ...         ...
# 99982         화양동             30            생활         40  ...         내국인
# 99991        고덕1동             30            생활         40  ...         내국인
# 99993         창4동             30            생활         40  ...         내국인
# 99996        서초2동             30            생활         40  ...         내국인
# 99997       용산2가동             30            생활         40  ...         내국인
#
#        CSTMR_MEGA_CTY_NO CSTMR_MEGA_CTY_NM CSTMR_CTY_RGN_NO  CSTMR_CTY_RGN_NM  \
# 1                     11             서울특별시             1165               서초구
# 6                     11             서울특별시             1150               강서구
# 12                    11             서울특별시             1168               강남구
# 16                    11             서울특별시             1138               은평구
# 19                    11             서울특별시             1171               송파구
# ...                  ...               ...              ...               ...
# 99982                 41               경기도             4182               가평군
# 99991                 41               경기도             4136              남양주시
# 99993                 41               경기도             4117               안양시
# 99996                 43              충청북도             4311               청주시
# 99997                 11             서울특별시             1162               관악구
#
#       SEX_CTGO_CD  AGE_VAL FLC      AMT  CNT
# 1               2      20대   1   109290   18
# 6               2      20대   1  1461800  274
# 12              1      30대   3   230730   34
# 16              1      20대   2  1087940  154
# 19              1      40대   3  2569590  361
# ...           ...      ...  ..      ...  ...
# 99982           1   60대 이상   5    69940    6
# 99991           2      40대   3    68980   15
# 99993           2      40대   3    12200    3
# 99996           1      50대   4    50600   10
# 99997           1      40대   2    38640    7
#
# [11512 rows x 23 columns]

# %%
print(f"편의점 소비액 : {cov_df['AMT'].sum(axis=0):,}원")
# Out:
# 편의점 소비액 : 7,299,184,098원

# %% [markdown]
# #### 2-2-2. 강남구 소비액 분석하기
# * 이용 도시 내 지역 정보 : CTY_RGN_NM - 강남구

# %%
gangnam = bc_card[bc_card['CTY_RGN_NM'] == '강남구']
gangnam['AMT'].sum(axis=0)
# Out:
# 35535648502

# %% [markdown]
# #### 2-2-3. 강남구 편의점 소비액 분석하기

# %%
cov_gangnam =  gangnam[gangnam['TP_BUZ_NO'] == 4010]
cov_gangnam
# Out:
#        REG_YYMM  MEGA_CTY_NO MEGA_CTY_NM  CTY_RGN_NO CTY_RGN_NM  ADMI_CTY_NO  \
# 6        201906           11       서울특별시        1168        강남구     11680521
# 12       201906           11       서울특별시        1168        강남구     11680545
# 60       201906           11       서울특별시        1168        강남구     11680640
# 64       201906           11       서울특별시        1168        강남구     11680521
# 97       201906           11       서울특별시        1168        강남구     11680750
# ...         ...          ...         ...         ...        ...          ...
# 99701    201906           11       서울특별시        1168        강남구     11680650
# 99772    201906           11       서울특별시        1168        강남구     11680630
# 99827    201906           11       서울특별시        1168        강남구     11680720
# 99865    201906           11       서울특별시        1168        강남구     11680640
# 99903    201906           11       서울특별시        1168        강남구     11680640
#
#       ADMI_CTY_NM  MAIN_BUZ_CODE MAIN_BUZ_DESC  TP_GRP_NO  ... CSTMR_GUBUN  \
# 6            논현1동             30            생활         40  ...         내국인
# 12           압구정동             30            생활         40  ...         내국인
# 60           역삼1동             30            생활         40  ...         내국인
# 64           논현1동             30            생활         40  ...         내국인
# 97            수서동             30            생활         40  ...         내국인
# ...           ...            ...           ...        ...  ...         ...
# 99701        역삼2동             30            생활         40  ...         내국인
# 99772        대치4동             30            생활         40  ...         내국인
# 99827        일원본동             30            생활         40  ...         내국인
# 99865        역삼1동             30            생활         40  ...         내국인
# 99903        역삼1동             30            생활         40  ...         내국인
#
#        CSTMR_MEGA_CTY_NO CSTMR_MEGA_CTY_NM CSTMR_CTY_RGN_NO  CSTMR_CTY_RGN_NM  \
# 6                     11             서울특별시             1150               강서구
# 12                    11             서울특별시             1168               강남구
# 60                    41               경기도             4115              의정부시
# 64                    41               경기도             4113               성남시
# 97                    11             서울특별시             1168               강남구
# ...                  ...               ...              ...               ...
# 99701                 11             서울특별시             1168               강남구
# 99772                 11             서울특별시             1135               노원구
# 99827                 45              전라북도             4513               군산시
# 99865                 26             부산광역시             2671               기장군
# 99903                 11             서울특별시             1132               도봉구
#
#       SEX_CTGO_CD  AGE_VAL FLC       AMT   CNT
# 6               2      20대   1   1461800   274
# 12              1      30대   3    230730    34
# 60              1      40대   3   1059540   195
# 64              1      40대   3   2026160   320
# 97              1      30대   2  12673800  2279
# ...           ...      ...  ..       ...   ...
# 99701           1      40대   3  23756070  3203
# 99772           1      40대   2    184620    29
# 99827           1   60대 이상   5    110300    19
# 99865           1      30대   2    183520    22
# 99903           1      40대   4     89960    17
#
# [1050 rows x 23 columns]

# %%
gangnam_cov = bc_card[(bc_card['CTY_RGN_NM'] == '강남구')&(bc_card['TP_BUZ_NO'] == 4010)]
gangnam_cov['AMT'].sum(axis=0)
# Out:
# 707275140

# %% [markdown]
# #### 2-2-4. 강남주 거주 고객의 강남구 소비액
# * 이용자 거주 도시 내 지역 정보 : CSTMR_CTY_RGN_NM - 강남구
#
# * 강남구 거주 고객의 강남구 편의점 소비액
# * 강남구 비거주 고객의 강남구 편의점 소비액

# %%
gangnam_card = gangnam_cov[gangnam_cov['CSTMR_CTY_RGN_NM'] == '강남구']
gangnam_card.reset_index(drop=True, inplace=True)
gangnam_card['AMT'].sum(axis=0)
# Out:
# 288379890

# %%
nongangnam_card = gangnam_cov[gangnam_cov['CSTMR_CTY_RGN_NM'] != '강남구']
nongangnam_card['AMT'].sum(axis=0)
# Out:
# 418895250
